# %% [markdown]
# ### Read HATEBASE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize

# %%
dfs = pd.read_html('https://hatebase.org/search_results/language_id=eng%7Cpage=2')

# %%
len(dfs)
# Out:
# 25

# %%
dfs[0]
# Out:
#                                                 0        1  \
# 0        ars  (transliteration of ×¢×¨×¡â `ars)  English
# 1                          arsim  (plural of ars)  English
# 2                         arsit  (variant of ars)  English
# 3             Aunt Jane  (variant of Aunt Jemima)  English
# 4               Aunt Janes  (plural of Aunt Jane)  English
# 5                                     Aunt Jemima  English
# 6           Aunt Jemimas  (plural of Aunt Jemima)  English
# 7             Aunt Mary  (variant of Aunt Jemima)  English
# 8               Aunt Marys  (plural of Aunt Mary)  English
# 9            Aunt Sally  (variant of Aunt Jemima)  English
# 10            Aunt Sallys  (plural of Aunt Sally)  English
# 11                                            azn  English
# 12                          azns  (plural of azn)  English
# 13                                    bamboo coon  English
# 14          bamboo coons  (plural of bamboo coon)  English
# ...
